# %% [markdown]
# Day 39 – Tuple, Immutable vs Mutable, List Creation

# %%
# Create a tuple with fixed product categories like Electronics, Stationery, and Clothing.
fixed_products = ("Electronics","Stationary","Clothing")
print(fixed_products)
# Out:
# ('Electronics', 'Stationary', 'Clothing')
# tuple

# %%
# Create a list of products that can be updated dynamically.
products = ["Laptop","Mobile phone","Headphones"]
print(products)
# Out:
# ['Laptop', 'Mobile phone', 'Headphones']

# %%
# Ask the user to enter a new product and add it to the list.
new_product = input("Enter a product: ")
products.append(new_product)
print(products)
# Out:
# Enter a product: Charger
# ['Laptop', 'Mobile phone', 'Headphones', 'Charger']

# %%
# Ask the user to input the index of a product to remove it from the list.
remove_product = int(input("Enter a product to remove: "))
del products[remove_product]
print(products)
# Out:
# Enter a product to remove: 1
# ['Laptop', 'Headphones', 'Charger']

# %%
# Display the final list of products and the product categories.
print(fixed_products)
print(products)
# Out:
# ('Electronics', 'Stationary', 'Clothing')
# ['Laptop', 'Headphones', 'Charger']
