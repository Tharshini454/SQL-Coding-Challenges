# %% [markdown]
# Day 41 – Dictionary, Set, Frozenset

# %%
# Create a dictionary with student names as keys and their grades as values.
dictionary = {"Tharshini" : "A",
              "Swathi": "B",
              "Rakshana":"C"}
print(dictionary)
# Out:
# {'Tharshini': 'A', 'Swathi': 'B', 'Rakshana': 'C'}

# %%
# Allow the user to add or update grades for at least 3 students.
for i in range(3):
  name = input("Enter name: ")
  grade = input("Enter grade: ")
  dictionary [name] = grade
print(dictionary)
# Out:
# Enter name: Subesh
# Enter grade: A
# Enter name: Anil
# Enter grade: C
# Enter name: Moni
# Enter grade: B
# {'Tharshini': 'A', 'Swathi': 'B', 'Rakshana': 'C', 'Subesh': 'A', 'Anil': 'C', 'Moni': 'B'}

# %%
# Create a set of hobbies and allow the user to input at least 3 hobbies.
hobbies = set()
for i in range(3):
  hobby = input("Enter your hobby: ")
  hobbies.add(hobby)
print(hobbies)
# Out:
# Enter your hobby: Reading
# Enter your hobby: Gardening
# Enter your hobby: Cycling
# {'Gardening', 'Cycling', 'Reading'}

# %%
# Convert the set of hobbies into a frozenset and display it.
frozen_hobby = frozenset(hobbies)
print(frozen_hobby)
# Out:
# frozenset({'Gardening', 'Cycling', 'Reading'})
