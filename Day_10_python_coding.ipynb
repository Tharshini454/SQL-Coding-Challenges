# %% [markdown]
# Day 38 – String Methods and Slicing

# %%
# Ask the user to input a sentence (representing feedback).
feedback = input("Enter your feedback: ")
# Out:
# Enter your feedback: The data quality in this dataset is very good and data is well organized

# %%
# Count how many words are in the sentence.
count = len(feedback.split())
print(f"Total words are: {count}")
# Out:
# Total words are: 14

# %%
# Check how many times the word “data” appears in the sentence, regardless of case.
data_count = feedback.lower().count("data")
print(f"Count of word 'data' is: {data_count}")
# Out:
# Count of word 'data' is: 3

# %%
# Extract and print the first 5 and last 5 characters of the feedback separately.
first5 = feedback[0:5]
last5 = feedback[-5:]
print(f"First 5 characters are: {first5}\nLast 5 characters are: {last5}")
# Out:
# First 5 characters are: The d
# Last 5 characters are: nized

# %%
# Reverse the sentence and print it.
reverse = feedback[::-1]
print(reverse)
# Out:
# dezinagro llew si atad dna doog yrev si tesatad siht ni ytilauq atad ehT
