# %% [markdown]
# Day 37 – Introduction to Programming Languages and Python
#  Project Title: Student Profile Creator

# %%
# Create variables to store the student’s name, age, and their favourite subjects they are enrolled in.
name = "Tharshini"
age = "21"
favt_subjects = ["Database","Networking","Front end development"]

# %%
# Display the student’s information in a user-friendly format.
print("STUDENT INFO")
print(f"Name : {name}\nAge : {age}\nFavourite subjects : {favt_subjects}")
# Out:
# STUDENT INFO
# Name : Tharshini
# Age : 21
# Favourite subjects : ['Database', 'Networking', 'Front end development']

# %%
# Ask the student to enter their favourite subject and add it to their favourite subjects variable & display the updated list of subjects.
favourite_sub = input("Enter your favourite subject :")
favt_subjects.append(favourite_sub)
print(favt_subjects)
# Out:
# Enter your favourite subject :Data structures
# ['Database', 'Networking', 'Front end development', 'Data structures']
